# %% [markdown]
# # Job Description Notebook
#
# The purpose of this project was to explore job postings for common tech fields. Although we certainly could expand the scraping we initially scraped for:
# * Data Scientist
# * Data Analyst
# * Data Engineer
# * Front End Developer
# * Back End Developer
# * Fullstack Developer
#
# We scraped from numerous big tech cities including:
# * San Francisco
# * Denver
# * New York
# * Seattle
# * Portland
#
# Our initial goal was to determine what the most important and desired skills, packages, tech, etc. were from each field. However, it developed into an interesting project in determining how different some of these fields are actually from each other.
#
# The web scraping was done by Leo Walker (https://github.com/leowalker89).

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import my_nlp_lib as my_lib
import spacy
import numpy as np
from sklearn.decomposition import NMF
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(12345)
import dill
# Out:
# /Users/Rebecca/anaconda3/lib/python3.6/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.22) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ### Load spacy
# Spacy is similar to NLTK but a lot faster and I think it provides a lot better results.

# %%
nlp = spacy.load('en')

# %% [markdown]
# ### Load data into pandas

# %%
df = pd.read_csv("multi_job_info1.csv", header = 1, encoding = 'latin-1')

# %%
df.head(5)
# Out:
#    1        category                    title       company  \
# 0  2  data scientist          Data Scientist,  Cybercoders,
# 1  3  data scientist   Data Scientist Intern,  Cybercoders,
# 2  4  data scientist          Data Scientist,      Tealium,
# 3  5  data scientist          Data Scientist,         GDIT,
# 4  6  data scientist  Senior Data  Scientist,       Hookit,
#
#                 location     date  \
# 0  san-diego,california,  11/7/17
# 1  san-diego,california,  11/7/17
# 2  san-diego,california,  11/7/17
# 3  san-diego,california,  11/7/17
# 4  san-diego,california,  11/7/17
#
#                                             job_desc
# 0   Data Scientist If you are a Data Scientist wi...
# 1   Data Scientist Intern If you are looking to s...
# 2   WHO WE ARETealium is the leader in real time ...
# 3   General Dynamics Health Solutions ARMA would ...
# 4   Senior Data ScientistAt Hookit we help brands...

# %% [markdown]
# Alright the strings aren't the cleanest but for our purposes they look fine. There is a structure to the data, so lets shuffle it and view another section.

# %%
shuffled_df = df.sample(frac = 1, random_state = 42)
shuffled_df.head(10)
# Out:
#          1              category  \
# 1429  1431    back end developer
# 231    233        data scientist
# 2019  2021  full stack developer
# 297    299        data scientist
# 2053  2055  full stack developer
# 298    300        data scientist
# 1837  1839  full stack developer
# 719    721          data analyst
# 70      72        data scientist
# 1483  1485    back end developer
#
#                                                   title             company  \
# 1429                                     Web Developer,  ISO International,
# 231                   Data Scientist - Marketing Cloud,             Oracle,
# 2019                                     Web Developer,              Kelly,
# 297         Machine Learning Engineer / Data Scientist,      BetterCompany,
# 2053              Full-Stack Web Developer; US Citizen,       CGS Staffing,
# 298                          Data Scientist - Contract,        Cybercoders,
# 1837  Senior Full Stack Software Development Enginee...             Zillow,
# 719                                       Data Analyst,       Silverspring,
# 70    Cloud DATA SCIENTIST - Big Data Platform Team ...             Oracle,
# 1483             Principal Software Engineer - Backend,           Highspot,
#
#                        location     date  \
# 1429      san-diego,california,  11/7/17
# 231            orlando,florida,  11/7/17
# 2019           orlando,florida,  11/7/17
# 297   san-francisco,california,  11/7/17
# 2053             houston,texas,  11/7/17
# 298   san-francisco,california,  11/7/17
# 1837        seattle,washington,  11/7/17
# 719       san-diego,california,  11/7/17
# 70             denver,colorado,  11/7/17
# 1483        seattle,washington,  11/7/17
#
#                                                job_desc
# 1429   We are seeking a Web Developer to join our te...
# 231    Designs develops and programs methods process...
# 2019   Kelly Services is actively seeking a Full Sta...
# 297    BetterCompany is looking for a highly motivat...
# 2053   We are looking for a Full Stack Developer to ...
# 298    Data Scientist Contract Data Scientist 6 mont...
# 1837   About the roleFinding the right place to rent...
# 719    Job Description Silver Spring Networks is loo...
# 70     Provides direction and specialist knowledge i...
# 1483   We are a community of engineers working at th...

# %% [markdown]
# This reveals some more cleaning, we have some empty strings that must not have had a result in the scrape search query these returned title, company, location, job_desc for results.
# Lets clean those and drop the first column. Lets also clean location and strip the commas where we can.

# %%
title_dropped= shuffled_df[shuffled_df['title'] != 'title'].drop('1', axis = 1)
title_dropped['location'] = title_dropped['location'].str.strip(',').str.replace(repl= ', ', pat = ',')
title_dropped['title'] = title_dropped['title'].str.strip(',')
title_dropped['company'] = title_dropped['company'].str.strip(',')
cleaned_df = title_dropped.copy()
label_dict = {'front end developer' : 0,
              'data scientist' : 1,
              'back end developer' : 2,
              'data analyst' : 3,
              'data engineer' : 4,
              'full stack developer' : 5}


cleaned_df['num_labels'] = cleaned_df['category'].map(label_dict)

# %%
cleaned_df.head(10)
# Out:
#                   category                                              title  \
# 1429    back end developer                                      Web Developer
# 231         data scientist                   Data Scientist - Marketing Cloud
# 2019  full stack developer                                      Web Developer
# 297         data scientist         Machine Learning Engineer / Data Scientist
# 2053  full stack developer               Full-Stack Web Developer; US Citizen
# 298         data scientist                          Data Scientist - Contract
# 1837  full stack developer  Senior Full Stack Software Development Enginee...
# 719           data analyst                                       Data Analyst
# 70          data scientist  Cloud DATA SCIENTIST - Big Data Platform Team ...
# 1483    back end developer              Principal Software Engineer - Backend
#
#                 company                   location     date  \
# 1429  ISO International      san-diego, california  11/7/17
# 231              Oracle           orlando, florida  11/7/17
# 2019              Kelly           orlando, florida  11/7/17
# 297       BetterCompany  san-francisco, california  11/7/17
# 2053       CGS Staffing             houston, texas  11/7/17
# 298         Cybercoders  san-francisco, california  11/7/17
# 1837             Zillow        seattle, washington  11/7/17
# 719        Silverspring      san-diego, california  11/7/17
# 70               Oracle           denver, colorado  11/7/17
# 1483           Highspot        seattle, washington  11/7/17
#
#                                                job_desc  num_labels
# 1429   We are seeking a Web Developer to join our te...           2
# 231    Designs develops and programs methods process...           1
# 2019   Kelly Services is actively seeking a Full Sta...           5
# 297    BetterCompany is looking for a highly motivat...           1
# 2053   We are looking for a Full Stack Developer to ...           5
# 298    Data Scientist Contract Data Scientist 6 mont...           1
# 1837   About the roleFinding the right place to rent...           5
# 719    Job Description Silver Spring Networks is loo...           3
# 70     Provides direction and specialist knowledge i...           1
# 1483   We are a community of engineers working at th...           2

# %% [markdown]
# This looks a lot better, I'm happy with this. Given more time I'd like to strip the company name from the job description if it's there, but that will take some thinking. Instead I'll probably just make company names stop words later.
#
#
#
#
#
# Now lets add all of the job descriptions to a corpus and the company names to a stop list, we will replace spaces with underscores, it won't catch all of them but hopefully it will get most.

# %%
corpus = list(cleaned_df['job_desc'])
companys_add_stoplist = list(cleaned_df['company'].str.lower())

# %% [markdown]
# The below function processes and clean each description in the corpus. It:
# * Strips punctuation
# * Removes unicode
# * Runs the doc through spacy
# * Lemmatizes and tokens all words
# * Keeps only Adjectives, Adverbs, Nouns, Proper Nouns, and Verbs (may change later)
# * Removes stop words and rejoins as strings.
#
# I have already prebuilt the stop words based on iterations of this model. A common problem was removing a lot of equal opportunity employment requirements. Although certainly important not necessarily useful for this project.

# %%
clean_corpus = [my_lib.process_string(doc, stoplist = companys_add_stoplist) for doc in corpus]

# %% [markdown]
# Lets do a quick comparison of before and after:
#
# Before:

# %%
corpus[42]
# Out:
# ' Data Center Network Engineering ConsultantJob Summary The project scope will be to integrate a newly acquired company into our 2 main data center locations The job responsibilities will include working with network hardware vendors Telco Service Providersand client technology departments to provide a seamless transition of services for our new clientbase Job Functions Ability to alter device configuration for logical or physical changes to maintain service integrity Perform Routing Switching Network upgrades and configuration Coordinate with vendors and technology partners to insure proper physical layer connectivity Perform circuit turn up testing and handoff to operations team for acceptance Create and update as built documentation and Visio diagrams Implement configurations or compliance changes with HPNA NCM or NCS scripts Executes with quality while completing tasks on time and on budget Proactively engaged to identify opportunities and implement enhancements of data network Engaged in the implementation and support of critical infrastructure platforms used in theoperation of small branch locations through call center campus and datacenter locations Provide high level of customer service to the internal client base Ability to effectively communicate highly technical options solutions Ability to support 24x7x365 operational and project related assignments Responsible for overall network troubleshooting and support of corporate internal networkRequired Skills 5 years of experience in a Data Center Network Engineering and Support environment CCNP CCNA certification preferred or equivalent work experience Strong knowledge of Cisco hardware and software platforms HP network knowledge a bonus Functional knowledge of routing protocols BGP MPLS EIGRP OSPF etc Functional level knowledge of WAN technologies MPLS OC 192 Carrier Ethernet etc Experience maintaining and troubleshooting a large enterprise WAN LAN data networks Ability to deliver on complex project requirements and tasks Familiar with network design and network management best practices Excellent customer service and detailed documentation skills Able to work within a customer oriented positive team environment Strong interpersonal oral visual and written communication skills Ability to meet deadlines and commitments while multitasking among concurrent projectsPREFERRED SKILLS Cisco Nexus 9000 7000 5000 and 2000 series switches Cisco ASR routers Cisco IOS NX OS and IOS XE experience Experience with tag switching and EoMPLS implementations Riverbed Cascade VitalSuite and Cisco Prime management platform experience Network trace capture and analysis skill set Scripting Knowledge of TCL Python or Perl Microsoft Word Excel PowerPoint and Visio expertise College degree ,'

# %% [markdown]
# After:

# %%
clean_corpus[42]
# Out:
# 'center network engineering consultantjob summary project scope integrate newly acquire main datum center responsibility network hardware vendor telco providersand technology department seamless transition clientbase functions alter device configuration logical physical maintain integrity perform routing switching network upgrade configuration coordinate vendor technology insure proper physical layer connectivity perform circuit turn testing handoff operation acceptance create update documentation visio diagram implement configuration hpna ncm ncs script execute quality task budget proactively engage identify implement enhancement datum network engage implementation critical infrastructure platform theoperation small branch center campus datacenter level internal effectively communicate highly technical option operational project related assignment responsible overall network troubleshooting internal networkrequired skills center network engineering ccnp ccna certification equivalent strong knowledge cisco hardware software platform network knowledge functional knowledge routing protocol bgp mpls eigrp ospf functional level knowledge wan technology mpls oc carrier ethernet maintain troubleshoot large enterprise wan lan datum network complex project task familiar network design network management practice excellent detailed documentation orient positive strong interpersonal oral visual write communication meet deadline commitment multitask concurrent projectspreferred cisco nexus series switch cisco asr router cisco ios nx os ios xe tag switching eompls implementation riverbed cascade vitalsuite cisco prime management platform network trace capture analysis set scripting knowledge tcl python perl microsoft word excel powerpoint visio expertise college degree'

# %% [markdown]
# Okay well that actually looks pretty good, it looks like we've captured the important words and gotten rid of the unimportant words, at least for our scenario.
#
# Great now lets copy it so that if while we are working with it we screw something up we don't have to clean it all over again. and then run it through a vectorizer. This vectorizer uses sklearns tfidfvectorizer or the countvectorizer depending on use case it then returns the vocabulary and the vectorizer for use in NMF. The NMF is simply sklearns NMF class

# %%
working_corpus = clean_corpus.copy()
vocabulary, vect_model = my_lib.build_text_vectorizer(working_corpus,
                             use_tfidf=True,
                             max_features=2000)
word_mat = vect_model.transform(working_corpus).toarray()

# Find latent topics using our NMF model.
factorizer = NMF(n_components=6, alpha=0.5, l1_ratio=0.1, verbose=0)
W = factorizer.fit_transform(word_mat)
H = factorizer.components_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e60891e7163c> in <module>()
#       3 vocabulary, vect_model = my_lib.build_text_vectorizer(working_corpus,
#       4                              use_tfidf=True,
# ----> 5                              max_features=2000)
#       6 word_mat = vect_model.transform(working_corpus).toarray()
#       7
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# To view the topics we can simply run a loop over the sorted arguments of the most influential features for each vector, then use those indexes to fetch the words from the vocab list.

# %%
for i, row in enumerate(H):
        num_words = np.argsort(row)[::-1][:50]
        print ('Topic', i)
        print (' '.join(vocabulary[num_words]), '\n')
# Out:
# Topic 0
# web end developer javascript css html design development website user php application browser mobile responsive code html5 jquery ui ux css3 understanding framework content creative page knowledge project interface create angular cross designer technology strong develop marketing react bootstrap digital standard platform wordpress app graphic js need maintain compatibility photoshop
#
# Topic 1
# datum hadoop engineer etl spark pipeline platform warehouse hive digital aws processing nosql python technology engineering tool source scala kafka cloud scale large implement infrastructure analytic sql database various modern redshift azure hbase scalable lake process ingestion architecture minimum architect set pig design streaming model governance store quality enable modeling
#
# Topic 2
# software development application design technology java technical stack test agile engineer web develop architecture cloud code engineering framework developer testing api spring knowledge computer tool integration strong lead database continuous problem project aws platform security write end need javascript process practice backend js programming scrum python react science node communication
#
# Topic 3
# datum analysis analyst analytic management information project reporting analyze process analytical sql perform excel knowledge statistical develop program database create healthcare quality level decision strong identify need research insight advanced manage internal communication key degree intelligence complex strategy analytics maintain tool access communicate risk multiple trend technical microsoft clinical marketing
#
# Topic 4
# machine scientist learning science datum model algorithm learn statistical python analytic predictive insight technique advanced marketing analysis research problem quantitative engineering modeling statistics deep lead mining ml large computer language method solve statistic mathematics phd physics unstructured develop ai visualization tool field experiment tensorflow sas states spark united optimization complex
#
# Topic 5
# net asp web sql mvc developer server application stack microsoft development angular software api vb object senior azure jquery database services entity wcf studio framework javascript windows develop procedure visual design strong knowledge store plus topic oriented core css programming associated ajax architect rest project charlotte programmer tfs write ssis

# %% [markdown]
# Alright well this topics actually look pretty good. Based on this information I would hypothesize that:
# * Topic 0 = Front End Developer
# * Topic 1 = Data Scientist
# * Topic 2 = Back End Developer
# * Topic 3 = Data Analyst
# * Topic 4 = Data Engineer
# * Topic 5 = Full Stack (maybe, software programmer)
#
# Lets create some labels and do some exploration.

# %%
labels = W.argmax(axis=1)
for i in range(0, W.shape[1]):
    print ("Topic {} contains {} documents.".format(i, np.sum(labels == i)))
# Out:
# Topic 0 contains 520 documents.
# Topic 1 contains 185 documents.
# Topic 2 contains 506 documents.
# Topic 3 contains 469 documents.
# Topic 4 contains 239 documents.
# Topic 5 contains 115 documents.

# %%
real_labels = cleaned_df['num_labels'].ravel()

# %%
pca = PCA(n_components = 15)
transform_mat = pca.fit_transform(word_mat)
my_lib.plot_embedding(transform_mat, real_labels)
plt.show()

# %%
pca = PCA(n_components = 15)
transform_mat = pca.fit_transform(word_mat)
my_lib.plot_embedding(transform_mat, labels)
plt.show()

# %% [markdown]
# This is interesting! First of all it appears that although we scraped an equal amounts of each job by classifier, topic modeling, suggests that there are clearly more people looking for web development jobs (either front end (0) or back end (2)). Based on the embedded PCA reduced plot, color aside, there is perhaps two groups. A left and a right group. Using the colors as categories this plot actually provides a lot of information. Assuming 0's and 2's are web developers, there appears to be a wide range of descriptions. Similarly if I'm correct in hypothesizing that 5 is full stack, there is certainly a logical overlap. Looking at the 'data fields. We also see some interesting stuff. First off all of the data fields(1, 3, 4) are clustered on the left of the plot. This suggest there is certainly a difference in requested skills and descriptions between 'data' folk and 'web' folk. Further more it looks as if data science (1) is nested with analytics almost as if data science is specialized subset of skills of data analytics, which once again is logical. The data engineers (4) are nested somewhere in between back end(2 ) and the data analyst/scientist (1,3) jobs. This once again is a somewhat logical conclusion. If I can get the original identification of the title we scraped I would certainly like to compare the before and after.
#
# ##Want to discuss differences between real_labels and classified labels

# %%
# tsne = TSNE(verbose = 1)
# transform_mat = tsne.fit_transform(X)
# my_lib.plot_embedding(transform_mat, labels)
# plt.show()

# %% [markdown]
# TSNE showed a similar conclusion, but it is nowhere near as clear.

# %%
pca = PCA(n_components = 15)
transform_mat = pca.fit_transform(word_mat)
my_lib.plot_embedding3d(transform_mat, real_labels)
plt.savefig('image.png')
plt.show()

# %% [markdown]
# Adding a third component begins to separate the 1's, 4's and 3's, but not by much. This can be seen better in plotly representations in the attached file 'job_descriptions_label.html'. For whatever reason matplotlibs Set1 didn't show colors for 4 and 5 so I had to use a different colormap.

# %%
my_lib.plot_embedding3dplotly(transform_mat, labels, filename = 'job_descriptions_label.html')

#this will take awhile to load

# %%
my_lib.plot_embedding3dplotly(transform_mat, real_labels, filename = 'job_descriptions_real_label.html')

# %% [markdown]
# Now lets only view the data science jobs classified by the topic modeler I created.

# %%
mask = labels == 4
corpus_array = np.array(working_corpus)
ds_corpus = list(corpus_array[mask])
vectorizer, vocabulary = my_lib.build_text_vectorizer(ds_corpus,
                             use_tfidf=True,
                             max_features=500)
word_mat = vect_model.transform(ds_corpus).toarray()

# Find latent topics using our NMF model.
factorizer = NMF(n_components=1, alpha=0.5, l1_ratio=0.2, verbose=0)
new_W = factorizer.fit_transform(word_mat)
new_H = factorizer.components_
new_labels = new_W.argmax(axis=1)

# %%
for i, row in enumerate(new_H):
        num_words = np.argsort(row)[::-1][:100]
        print ('Topic', i)
        print (' '.join(vocabulary[num_words]), '\n')
# Out:
# Topic 0
# datum science machine scientist model learning learn analysis analytic develop development problem lead technical engineering algorithm technology insight marketing statistical tool advanced large research process technique python need knowledge software computer application cloud solve complex design predictive engineer strong platform language modeling project source degree analyze quantitative implement sql deep create write field set mining hadoop relate decision communication statistics method spark organization programming management information area analytics statistic processing identify analytical java program ml senior database scale sale communicate focus sas understand improve code innovative level visualization understanding user result highly question unstructured mathematics expert optimization manager market group

# %% [markdown]
# ## Web App (In development code)
# Below this is a test experiment for a bootstrapped web app to make recommendations on words to beter indentify what should be in ones resume. It is unfinished, I would like to add stemming, and remove words two letters or less.

# %%
test_string = '''SELECT PROJECTS
Image Captioning for Augmented Reality Sales — Walmart Data https://github.com/mhmulder/picture_captioning_capstone
● Scraped web data in order to create an image captioning net that could be used to make sales recommendations based o  of an image
● Tech Used: CNN, LSTM, AWS (Cloud), Keras, NLP, Image classification, Python Analyzing Churn for a Ride Sharing Company— Galvanize
https://github.com/mhmulder/churn_study
● Modeled churn data using a gradient boosting classifier to make predictions and give recommendations for a major ride sharing company
● Tech Used: Gradient Boosting, Gridsearch, Scikit Learn, Seaborn, Python Using Statistical Methods to Create Best In Class Medical
Products — Next Frontier Biosciences https://dspace.library.colostate.edu/handle/10217/180351
● Utilized Design of Experiment and regression analysis to optimize properties in drug development
● Tech Used: JMP, Excel SELECT EXPERIENCE
Next Frontier Biosciences, CO — Formulation Scientist | Consultant June 2016 - December 2017
● Designed multi-million dollar manufacturing models spanning 8 year forecasts
● Researched, developed and manufactured 18 products from idea to launch
Focused Labs Oils, CO — Associate January 2016 - May 2016
● Projected a $300,000 increase in profits based on computational modeling in ASPEN, Minitab, Excel and Matlab
● Recommended 4 major process changes resulting in a 152% projected increase in ROI with their current extractor and a 283% increase in ROI for a modified extractor
Phillips 66 Center for Innovation Lab at CU, CO — Researcher January 2015 - May 2015
● Innovated and analyzed future energy saving gas separation devices
E. Pira-Chiara Boschis Winery, Piedmont, Italy — Winery Assistant
2013 Harvest
● Experienced first-hand international marketing, sales and culture EDUCATION
Galvanize Inc., CO — Data Science Immersive
● Applied various data science techniques to business cases with real data
● Specialized in regression, neural nets, and Bayesian statistics
● Independently took on additional courses through Coursera including
Andrew Ng’s deep learning and neural nets course
University of Colorado, CO — B.S. Chemical Engineering | B.A. Economics — GPA 3.61/4.00
● Built a strong foundation in statistics and calculus while applying econometrics and applied mathematics to engineering problems
● Developed a passion for learning, especially in predictive modeling SKILLS
Technical Languages
● Python, SQL, MATLAB
● Mild experience in: R, VBA
Analytical Skills
● Regression, Random Forest, Neural Nets, Gradient Boosting, Design of Experiment, Visualization, SVM, Machine Learning, NLP, AWS
Select Technical Skills
● Product Development, Scale Up, Manufacturing, Paired Programming, Leadership, Economic Analysis
Select Software Packages / Libraries
● PostgreSQL, JMP, Minitab, Aspen, Mathematica, Polymath, Microsoft Project, Microsoft Visio'''

# %%
clean_test = my_lib.process_string(test_string, stoplist = companys_add_stoplist)

# %%
clean_test
# Out:
# 'select project image captioning augmented reality sale walmart httpsgithubcommhmulderpicture_captioning_capstone scrap web datum order create image caption net sale recommendation image tech cnn lstm aws cloud keras nlp image classification python analyzing churn ride sharing galvanize httpsgithubcommhmulderchurn_study model churn datum gradient boost classifier prediction recommendation major ride share tech gradient boosting gridsearch scikit learn seaborn python statistical methods create class medical products frontier biosciences httpsdspacelibrarycolostateeduhandle10217180351 utilize design experiment regression analysis optimize property drug development tech jmp excel select frontier biosciences formulation scientist consultant june december design multimillion dollar manufacturing model span forecast researched develop manufacture idea launch focused labs oils associate january project increase profit computational modeling aspen minitab excel matlab recommend major process result project increase roi current extractor increase roi modify extractor phillips center innovation lab cu researcher january innovated analyze future energy save gas separation device e pirachiara boschis winery piedmont italy winery assistant harvest firsthand international marketing sale galvanize science immersive applied various science technique case datum specialized regression neural net bayesian statistic independently additional course coursera andrew ngs deep learning neural net course university colorado bs chemical engineering ba economics gpa strong foundation statistic calculus econometric mathematic engineering problem develop learn especially predictive modeling skills technical languages python sql matlab mild r vba analytical skills regression random forest neural nets gradient boosting design experiment visualization svm machine learning nlp aws select technical skills development scale manufacturing paired programming leadership economic analysis select software packages libraries postgresql jmp minitab aspen mathematica polymath microsoft project microsoft visio'

# %%
test_word_mat = vect_model.transform(clean_test).toarray()

# %%
test_new_W = factorizer.transform(test_word_mat)
test_new_H = factorizer.components_
new_labels = test_new_W.argmax(axis=1)

# %%
new_labels[0]
# Out:
# 4

# %%
test_new_W
# Out:
# array([[ 0.        ,  0.        ,  0.00795004,  0.0286394 ,  0.09791659,
#          0.04939011]])

# %%
for i, row in enumerate(test_new_H):
        num_words = np.argsort(row)[::-1][:100]
        print ('Topic', i)
        print (' '.join(vocabulary[num_words]), '\n')
# Out:
# Topic 0
# web end developer javascript css html design development website user php application browser mobile responsive code html5 jquery ui ux css3 understanding framework content creative page knowledge project interface create angular cross designer technology strong develop marketing react bootstrap digital standard platform wordpress app graphic js need maintain compatibility photoshop stack brand usability api sass implement commerce mysql write proficient ajax interactive git email cms tool seek plus management adobe library modern server coding collaborate testing required json practice update senior ecommerce ruby seo magento technical agency dynamic cod dice language quality feature skills reusable follow node closely deep version
#
# Topic 1
# datum hadoop engineer etl spark pipeline platform warehouse hive digital aws processing nosql python technology engineering tool source scala kafka cloud scale large implement infrastructure analytic sql database various modern redshift azure hbase scalable lake process ingestion architecture minimum architect set pig design streaming model governance store quality enable modeling building required science multiple emr stream optimal cassandra analytics integration traditional s3 insight ecosystem transformation select language deploy kinesis skills relational expertise unstructured responsible collect programming hdfs production create schema scripting batch mysql intelligence bi mapreduce dataset structure extract metadata art enterprise case define sqoop apache java google need play
#
# Topic 2
# software development application design technology java technical stack test agile engineer web develop architecture cloud code engineering framework developer testing api spring knowledge computer tool integration strong lead database continuous problem project aws platform security write end need javascript process practice backend js programming scrum python react science node communication senior delivery degree enterprise management server solve level deployment complex participate understanding rest services sql highly functional restful quality feature implement focus implementation object automation learn equivalent information scalable user demonstrate language orient methodology organization git large linux scale relational component review familiarity global qualifications maintain architect create plan automate
#
# Topic 3
# datum analysis analyst analytic management information project reporting analyze process analytical sql perform excel knowledge statistical develop program database create healthcare quality level decision strong identify need research insight advanced manage internal communication key degree intelligence complex strategy analytics maintain tool access communicate risk multiple trend technical microsoft clinical marketing function write problem improvement sas ensure department result tableau source model set understand plan query excellent assist organization financial lead metric recommendation development bi stakeholder duty individual responsible bachelor operational operation issue relate field design qualifications initiative visualization strategic procedure improve solve capability effectively group meet dashboard science present interpret
#
# Topic 4
# machine scientist learning science datum model algorithm learn statistical python analytic predictive insight technique advanced marketing analysis research problem quantitative engineering modeling statistics deep lead mining ml large computer language method solve statistic mathematics phd physics unstructured develop ai visualization tool field experiment tensorflow sas states spark united optimization complex actionable question processing decision mathematical scale sale technical nlp regression degree innovative area artificial scala expert neural personalization relate organization set structured natural cloud mentor ph target matlab dataset characteristic behavior feature analyze technology need omc implement strong analytics leverage result math small programming mission source identify demonstration space senior
#
# Topic 5
# net asp web sql mvc developer server application stack microsoft development angular software api vb object senior azure jquery database services entity wcf studio framework javascript windows develop procedure visual design strong knowledge store plus topic oriented core css programming associated ajax architect rest project charlotte programmer tfs write ssis ms developerlocation xml maintain soap agile foundation nc layer excellent developers json iis ssrs applications orient requirements complex tier component html view ideal custom oop w2 later resolve control backend dice query restful pattern kansas communication debug exist resume responsibilities seek possess skills direct bootstrap multiple thank middle currently major

# %%
DS_sorted_words = np.argsort(test_new_H[4])[::-1][:100]

# %%
DS_vocab = vocabulary[DS_sorted_words]
DS_set = set(DS_vocab)

# %%
my_set = set(clean_test.split(' '))

# %%
missing_words = []

for word in DS_set:
    if word not in my_set:
        missing_words.append(word)
        
print ('These are your missing words: {}'.format(' '.join(missing_words)))
# Out:
# These are your missing words: physics language processing source computer large identify ph advanced omc statistics tensorflow optimization unstructured actionable dataset insight algorithm mathematics expert states field senior quantitative need united leverage natural sas complex area technology behavior mathematical degree ml tool ai innovative feature question spark small organization research method space characteristic artificial set structured solve decision mission demonstration implement lead mentor scala mining analytic personalization relate target math analytics phd

# %%
len(missing_words
   )
# Out:
# 67

# %%
# Out:
# Michael Mulder Resume.pdf           job_descriptions_nlp_notebook.ipynb
# README.md                           job_descriptions_real_label.html
# __pycache__                         multi_job_info1.csv
# image.png                           my_nlp_lib.py
# job_descriptions_label.html         web_app

# %%
nlp_packages = [vectorizer, factorizer, vocabulary]

# %%
with open('web_app/static/model.pkl', 'wb') as f:
        pickle.dump(nlp_packages, f)

# %%
with open("web_app/static/dillmodel", "wb") as dill_file:
        dill.dump(nlp_packages, dill_file)
